# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

import warnings
warnings.filterwarnings('ignore')

df=pd.read_csv('sonar_zip/data/sonar_csv.csv')

# %%
df.head()
# Out:
#    attribute_1  attribute_2  attribute_3  attribute_4  attribute_5  \
# 0       0.0200       0.0371       0.0428       0.0207       0.0954
# 1       0.0453       0.0523       0.0843       0.0689       0.1183
# 2       0.0262       0.0582       0.1099       0.1083       0.0974
# 3       0.0100       0.0171       0.0623       0.0205       0.0205
# 4       0.0762       0.0666       0.0481       0.0394       0.0590
#
#    attribute_6  attribute_7  attribute_8  attribute_9  attribute_10  ...  \
# 0       0.0986       0.1539       0.1601       0.3109        0.2111  ...
# 1       0.2583       0.2156       0.3481       0.3337        0.2872  ...
# 2       0.2280       0.2431       0.3771       0.5598        0.6194  ...
# 3       0.0368       0.1098       0.1276       0.0598        0.1264  ...
# 4       0.0649       0.1209       0.2467       0.3564        0.4459  ...
#
#    attribute_52  attribute_53  attribute_54  attribute_55  attribute_56  \
# ...

# %%
print(df.shape)
print(df['Class'].value_counts())
# Out:
# (208, 61)
# Mine    111
# Rock     97
# Name: Class, dtype: int64

# %%
df.columns
# Out:
# Index(['attribute_1', 'attribute_2', 'attribute_3', 'attribute_4',
#        'attribute_5', 'attribute_6', 'attribute_7', 'attribute_8',
#        'attribute_9', 'attribute_10', 'attribute_11', 'attribute_12',
#        'attribute_13', 'attribute_14', 'attribute_15', 'attribute_16',
#        'attribute_17', 'attribute_18', 'attribute_19', 'attribute_20',
#        'attribute_21', 'attribute_22', 'attribute_23', 'attribute_24',
#        'attribute_25', 'attribute_26', 'attribute_27', 'attribute_28',
#        'attribute_29', 'attribute_30', 'attribute_31', 'attribute_32',
#        'attribute_33', 'attribute_34', 'attribute_35', 'attribute_36',
#        'attribute_37', 'attribute_38', 'attribute_39', 'attribute_40',
#        'attribute_41', 'attribute_42', 'attribute_43', 'attribute_44',
#        'attribute_45', 'attribute_46', 'attribute_47', 'attribute_48',
#        'attribute_49', 'attribute_50', 'attribute_51', 'attribute_52',
# ...

# %%
df.isnull().sum()
# Out:
# attribute_1     0
# attribute_2     0
# attribute_3     0
# attribute_4     0
# attribute_5     0
#                ..
# attribute_57    0
# attribute_58    0
# attribute_59    0
# attribute_60    0
# Class           0
# Length: 61, dtype: int64

# %%
df.dtypes
# Out:
# attribute_1     float64
# attribute_2     float64
# attribute_3     float64
# attribute_4     float64
# attribute_5     float64
#                  ...
# attribute_57    float64
# attribute_58    float64
# attribute_59    float64
# attribute_60    float64
# Class            object
# Length: 61, dtype: object

# %%
z=df.drop(['Class'],axis=1)
y=df['Class']

# %%
y=pd.get_dummies(y,drop_first=True)

# %%
y.sample(5)
# Out:
#      Rock
# 26      1
# 1       1
# 196     0
# 139     0
# 67      1

# %%
pd.value_counts(y.values.flatten())
# Out:
# 0    111
# 1     97
# dtype: int64

# %%
ztrain,ztest,ytrain,ytest = train_test_split(z,y)
print(ztrain.shape)
print(ztest.shape)
print(ytrain.shape)
print(ytest.shape)
# Out:
# (156, 60)
# (52, 60)
# (156, 1)
# (52, 1)

# %%
model1 = keras.Sequential([
    keras.layers.Dense(60,input_shape=(60,),activation='relu'),
    keras.layers.Dense(40,activation='relu'),
    keras.layers.Dense(20,activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
])

model1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model1.fit(ztrain,ytrain,epochs=100)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 4ms/step - loss: 0.7050 - accuracy: 0.4707
# Epoch 2/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6909 - accuracy: 0.5266
# Epoch 3/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6762 - accuracy: 0.6887
# Epoch 4/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6676 - accuracy: 0.6277
# Epoch 5/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6518 - accuracy: 0.6853
# Epoch 6/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6527 - accuracy: 0.6713
# Epoch 7/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6328 - accuracy: 0.6605
# Epoch 8/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6200 - accuracy: 0.6740
# Epoch 9/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5984 - accuracy: 0.6956
# Epoch 10/100
# ...

# %%
model1.evaluate(ztest,ytest)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5934 - accuracy: 0.8077
# [0.5933818221092224, 0.807692289352417]

# %%
ypredict = model1.predict(ztest)
ypredict = np.round(ypredict)

# %%
print('Classification report : \n',classification_report(ytest,ypredict))
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.85      0.79      0.82        29
#            1       0.76      0.83      0.79        23
#
#     accuracy                           0.81        52
#    macro avg       0.81      0.81      0.81        52
# weighted avg       0.81      0.81      0.81        52

# %% [markdown]
# ### Applying Dropout layers

# %%
model2 = keras.Sequential([
    keras.layers.Dense(60,input_shape=(60,),activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(40,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(20,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1,activation='sigmoid')
])

model2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model2.fit(ztrain,ytrain,epochs=100)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 2ms/step - loss: 0.7546 - accuracy: 0.4917
# Epoch 2/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7596 - accuracy: 0.4831
# Epoch 3/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7591 - accuracy: 0.4588
# Epoch 4/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7127 - accuracy: 0.4364
# Epoch 5/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6951 - accuracy: 0.5502
# Epoch 6/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6893 - accuracy: 0.5726
# Epoch 7/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6959 - accuracy: 0.5165
# Epoch 8/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6913 - accuracy: 0.5088
# Epoch 9/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6841 - accuracy: 0.5445
# Epoch 10/100
# ...

# %%
model2.evaluate(ztest,ytest)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5228 - accuracy: 0.8077
# [0.5227543115615845, 0.807692289352417]

# %%
ypredict2 = model2.predict(ztest)
ypredict2 = np.round(ypredict2)
print('Classification report : \n',classification_report(ytest,ypredict2))
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.88      0.76      0.81        29
#            1       0.74      0.87      0.80        23
#
#     accuracy                           0.81        52
#    macro avg       0.81      0.81      0.81        52
# weighted avg       0.82      0.81      0.81        52
